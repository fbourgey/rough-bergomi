# %% [markdown]
# <font color="orange">Weak approximations and VIX option price
# expansions in forward variance curve models</font>

# %% [markdown]
# Convention is different. The parameter $\eta$ in the paper must be
# replaced with $\eta \sqrt{2H}$

# %% [markdown]
# Given a kernel function $K(\cdot)$, consider the SDE for the instantaneous
# forward variance curve model
# $$
#     d\xi_t^u = \xi_t^u K(u,t) \, dW_t
# $$
# or equivalently, for all $u \geq T$,
# $$
#     \xi_T^u = \xi_0^u \exp \left\{ Z_T^u \right\}
# $$
# where
# $$
#     Z_T^u = -\frac{1}{2}\int_0^T K(u,t)^2 \, dt + \int_0^T K(u,t) \, dW_t.
# $$
#
# We approximte the
#
# $$
#     \text{VIX}_T^2
#     = \frac{1}{\Delta} \int_{T}^{T+\Delta} \xi_T^u \, du
#     = \frac{1}{\Delta} \int_{T}^{T+\Delta} \xi_0^u \exp \{Z_T^u\} \, du
# $$
#
# with a lognormal proxy
#
# $$
#     \text{VIX}_{T,P}^2 = \mathbb{E}[\text{VIX}_T^2]
#     \exp \left\{\frac{1}{\Delta} \int_{T}^{T+\Delta} \xi_0^u Z_T^u
#     \frac{du}{\mathbb{E}[\text{VIX}_T^2]}\right\}
# $$
#
# where the fair price of a VIX squared futures contract is given by
#
# $$
#     \mathbb{E}[\text{VIX}_T^2] = \frac{1}{\Delta}
#     \int_{T}^{T+\Delta} \xi_0^u du.
# $$
#
# We have that $\log \text{VIX}_{T,P}^2$ is normal with mean
#
# $$
#     \mu_{P} =
#     \log \mathbb{E}[\text{VIX}_T^2] -
#     \frac12 \int_0^T \left(\frac1\Delta
#     \int_{T}^{T+\Delta} \xi_0^u K(u,t)^2 \frac{du}{\mathbb{E}[\text{VIX}_T^2]} \right) \, dt
# $$
#
# and variance
#
# $$
#     \sigma_{P}^2 =
#     \int_0^T \left(\frac1\Delta
#     \int_{T}^{T+\Delta} \xi_0^u K(u,t) \frac{du}{\mathbb{E}[\text{VIX}_T^2]} \right)^2 \, dt
# $$
#
# ---
#
# We approximate the VIX option price by
# $$
#     \mathbb{E}[\varphi(\text{VIX}_{T}^2)] \approx
#     \mathbb{E}[\varphi(\text{VIX}_{T,P}^2)]
#     + \sum_{i=1}^{3} \gamma_i \, \partial_{\varepsilon}\left.\mathbb{E}\left[\varphi(\text{VIX}_{T,P}^2 \, e^{\varepsilon})\right]\right|_{\varepsilon=0}
# $$
#
# - The zeroth order approximation corresponds to a Black-Scholes price
# while the other terms are corrections based on Black-Scholes Greeks (delta, gamma, speed).
#
# - The coefficients $\gamma_i$ are deterministic integrals depending on the kernel.

# %%
# TODO: perform numerical tests for one-factor Bergomi model

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
from rbergomi import RoughBergomi
import matplotlib as mpl
import numpy as np
import seaborn as sns
from utils import xi0_heston, relative_error
from scipy import integrate, stats

sns.set_theme(context="talk")
sns.set_style("whitegrid")
mpl.rcParams["figure.figsize"] = (8, 6)
SEED = 1234
COLORS = sns.color_palette("tab10")

# %%
# simulation parameters
n_disc = 300
n_mc = 2 * 10**5
mats = {"1M": 1.0 / 12.0, "3M": 3.0 / 12.0, "6M": 6.0 / 12.0}

# %% [markdown]
# # Single case

# %% [markdown]
# Define the model parameters

# %%
params = {"H": 0.1, "eta": 1.0}
rho = -0.7
xi0 = lambda u: np.ones_like(u) * 0.235**2

rbergomi = RoughBergomi(rho=-0.7, xi0=xi0, params=params)

# %% [markdown]
# ## Price of VIX futures wrt the vol-of-variance $\eta$

# %%
tab_eta = np.linspace(0.1, 1.5, 10) * np.sqrt(2.0 * params["H"])

# Monte Carlo price
vix_fut_eta = {}
for month in mats:
    print(month)
    price = np.zeros_like(tab_eta)
    for i, eta in enumerate(tab_eta):
        rbergomi.eta = eta
        price[i] = rbergomi.price_vix_fut(
            T=mats[month], n_disc=n_disc, n_mc=n_mc, seed=SEED
        )
    vix_fut_eta[month] = price
# Out:
# 1M
# 3M
# 6M

# %%
# Approx price
vix_fut_eta_approx = {}
for month in mats:
    price = np.zeros_like(tab_eta)
    for i, eta in enumerate(tab_eta):
        rbergomi.eta = eta
        price[i] = rbergomi.price_vix_fut_approx(T=mats[month], order=3)
    vix_fut_eta_approx[month] = price

# %%
fig, ax = plt.subplots()
for i, month in enumerate(mats):
    ax.plot(
        tab_eta, 100.0 * vix_fut_eta[month], ".", color=COLORS[i], label=f"MC ({month})"
    )
    ax.plot(
        tab_eta,
        100.0 * vix_fut_eta_approx[month],
        "x",
        color=COLORS[i],
        label=f"approx ({month})",
    )
ax.set_xlabel("$\\eta$")
ax.set_ylabel("VIX futures price in %")
ax.legend(ncol=2)
plt.show()

# %% [markdown]
# ## Price of VIX futures wrt the maturity $T$

# %%
params = {
    "s0": 1.0,
    "xi0": lambda u: np.ones_like(u) * 0.235**2,
    "rho": -0.7,
    "H": 0.1,
    "eta": 1.0,
}

rbergomi = RoughBergomi(**params)

tab_t = np.linspace(1.0 / 365.0, 1.0, 10)

vix_fut_t = np.array(
    [rbergomi.price_vix_fut(T=T, n_mc=n_mc, n_disc=n_disc, rule="trap") for T in tab_t]
)

# %%
vix_fut_t_approx = np.array(
    [rbergomi.price_vix_fut_approx(T=T, order=3) for T in tab_t]
)

# %%
fig, ax = plt.subplots()
ax.plot(tab_t, 100.0 * vix_fut_t, ".", label="MC")
ax.plot(tab_t, 100.0 * vix_fut_t_approx, "x", label="approx")
ax.set_xlabel("$T$")
ax.set_ylabel("VIX futures price in %")
ax.legend()
plt.show()

# %% [markdown]
# ## Price of VIX ATM call options wrt the maturity $T$

# %%
vix_price_atm = np.array(
    [
        rbergomi.price_vix(k=0.0, T=T, n_mc=n_mc, n_disc=n_disc, rule="trap", opttype=1)
        for T in tab_t
    ]
)

# %%
vix_price_atm_approx = np.array(
    [rbergomi.price_vix_approx(k=0.0, T=T, order=3) for T in tab_t]
)

# %%
fig, ax = plt.subplots()
ax.plot(tab_t, vix_price_atm, ".", label="VIX ATM call")
ax.plot(tab_t, vix_price_atm_approx, "x", label="VIX ATM call approx")
ax.set_xlabel("$T$")
ax.legend()
plt.show()

# %% [markdown]
# ## VIX implied volatility

# %% [markdown]
# Plot VIX smiles as a function of $k=\log(K/F)$

# %%
# # Bourgey, De Marco, Delemotte - Smile Dynamics and Rough Volatility (except xi0)
# params = {
#     "xi0": lambda t: xi0(t, shape="contango"),
#     "rho": -0.62,
#     "H": 0.23,
#     "eta": 1.5,
# }

rho = -0.7
xi0 = lambda t: xi0_heston(t, shape="contango")

rbergomi = RoughBergomi(rho=rho, xi0=xi0, params=params)

# %%
# plot xi0
ts = np.linspace(1e-3, 1.0, 101)
fig, ax = plt.subplots()
ax.plot(ts, rbergomi.xi0(ts))
ax.set_xlabel("t")
ax.set_ylabel(r"$\xi_0(t)$")
plt.show()

# %%
# log moneyness
ks = np.linspace(-0.1, 0.5, 11)

# %%
# VIX implied volatilities from Monte Carlo
impvol_vix = {
    month: rbergomi.implied_vol_vix(k=ks, T=T, n_disc=n_disc, n_mc=n_mc, seed=SEED)
    for month, T in mats.items()
}

# %%
# VIX implied vol from weak approximation
impvol_vix_approx = {
    month: rbergomi.implied_vol_vix_approx(k=ks, T=T, order=3)
    for month, T in mats.items()
}

# %%
# VIX implied vol from expansion formula
impvol_vix_expansion = {
    month: rbergomi.implied_vol_vix_expansion(k=ks, T=T, order=1)
    for month, T in mats.items()
}

# %%
fig, ax = plt.subplots()
for i, month in enumerate(mats.keys()):
    ax.plot(ks, 100 * impvol_vix[month], ".", color=COLORS[i], label=f"{month}")
    ax.plot(ks, 100 * impvol_vix_approx[month], "x", color=COLORS[i])
    ax.plot(ks, 100 * impvol_vix_expansion[month], "+", color=COLORS[i])
ax.plot([], [], "kx", label="Approx")
ax.plot([], [], "k+", label="Expansion")
ax.set_xlabel(r"$k=\log(K/F)$")
ax.set_ylabel("VIX implied volatility in %")
ax.legend(loc="best")
ax.set_ylim(30, 100)
plt.show()

# %%
# relative errors
rel_error_approx = [
    relative_error(impvol_vix_approx[month], impvol_vix[month]) for month in mats
]
rel_error_expansion = [
    relative_error(impvol_vix_expansion[month], impvol_vix[month]) for month in mats
]

fig, ax = plt.subplots()
for i, month in enumerate(mats.keys()):
    ax.plot(ks, rel_error_approx[i], "x", color=COLORS[i])
    ax.plot(ks, rel_error_expansion[i], "+", color=COLORS[i])
    ax.plot([], [], ".", color=COLORS[i], label=f"{month}")
ax.plot([], [], "kx", label="Approx")
ax.plot([], [], "k+", label="Expansion")
ax.set_xlabel(r"$k=\log(K/F)$")
ax.set_ylabel("Relative error in %")
ax.legend(loc="best")
ax.set_ylim(-1e-3, 1e-3)
plt.show()

# %% [markdown]
# Plot term structure of VIX ATM implied volatility

# %%
Ts = np.linspace(1.0 / 12.0, 1.0, 21)

# %%
# Monte Carlo
impvol_vix_atm = np.array(
    [
        rbergomi.implied_vol_vix(k=0.0, T=T, n_disc=n_disc, n_mc=n_mc, seed=SEED)[0]
        for T in Ts
    ]
)

# %%
# Weak approx
impvol_vix_atm_approx = np.array(
    [rbergomi.implied_vol_vix_approx(k=0.0, T=T, order=3)[0] for T in Ts]
)

# %%
# Expansion
impvol_vix_atm_expansion = np.array(
    [rbergomi.implied_vol_vix_expansion(k=0.0, T=T, order=2) for T in Ts]
)

# %%
fig, ax = plt.subplots()
ax.plot(
    Ts,
    100 * impvol_vix_atm,
    ".",
    color=COLORS[i],
    label="MC",
)
ax.plot(
    Ts,
    100 * impvol_vix_atm_approx,
    "x",
    color=COLORS[i],
    label="approx",
)
ax.plot(
    Ts,
    100 * impvol_vix_atm_expansion,
    "+",
    color=COLORS[i],
    label="expansion",
)
ax.set_xlabel(r"$T$")
ax.set_ylabel("ATM VIX implied volatility in %")
ax.legend(loc="best")
# ax.set_ylim(20, 100)
plt.show()

# %% [markdown]
# # Mixed case

# %% [markdown]
# $
# \xi_T^u = \xi_0^u \left(
#     \lambda \exp\{Z_{T,1}^{u}\} + (1-\lambda) \exp\{Z_{T,2}^{u}\}
# \right)
# $
# where
#
# - $Z_{T,i}^{u} = -\frac12 \int_0^T K_i(u,t)^2 \, dt + \int_0^T K_i(u,t) \, dW_t$,

# %% [markdown]
# ## VIX implied volatility

# %% [markdown]
# Plot VIX smiles as a function of $k=\log(K/F)$

# %%
params = {"H": 0.1, "eta": 1.0}
rho = -0.7
xi0 = lambda u: np.ones_like(u) * 0.235**2
rbergomi = RoughBergomi(rho=rho, xi0=xi0, params=params)

n_disc = 300
n_mc = 2 * 10**5

ks = np.linspace(-0.1, 0.3, 11)
lbd = 0.3
eta_2 = 0.3

# %%
# Monte Carlo
impvol_vix_mixed = {
    month: rbergomi.implied_vol_vix(
        lbd=lbd, eta_2=eta_2, k=ks, T=T, n_disc=n_disc, n_mc=n_mc, seed=SEED
    )
    for month, T in mats.items()
}

# %%
# Gauss quadrature
# check for higher-order, is the integration range really correct? B seems different.
impvol_vix_mixed_approx = {
    month: np.asarray(
        rbergomi.implied_vol_vix_approx_mixed(
            lbd=lbd, volvol_2=eta_2, k=ks, T=T, order=3, n_quad=80
        )
    )
    for month, T in mats.items()
}

# %%
# SciPy quad - it can be unstable for order n >= 1
impvol_vix_mixed_approx_scipy = {
    month: np.asarray(
        rbergomi.implied_vol_vix_approx_mixed(
            lbd=lbd, volvol_2=eta_2, k=ks, T=T, order=3, n_quad=None
        )
    )
    for month, T in mats.items()
}
# Out:
# /Users/florianbourgey/projects/rough-bergomi/rbergomi.py:2299: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   price_1 = integrate.quad(integrand_1, left_1, right_1)[0]

# %%
# Hermite series
impvol_vix_mixed_approx_series = {
    month: np.asarray(
        rbergomi.implied_vol_vix_approx_mixed(
            lbd=lbd,
            volvol_2=eta_2,
            k=ks,
            T=T,
            order=0,
            n_trunc_herm=3,
        )
    )
    for month, T in mats.items()
}

# %%
# Lognormal approximation
impvol_vix_mixed_approx_lognorm = {
    month: np.asarray(
        rbergomi.implied_vol_vix_lognorm_approx_mixed(
            lbd=lbd, volvol_2=eta_2, k=ks, T=T, order=0
        )
    )
    for month, T in mats.items()
}

# %%
# Shifted Lognormal approximation
impvol_vix_mixed_approx_slognorm = {
    month: np.asarray(
        rbergomi.implied_vol_vix_shifted_lognorm_approx_mixed(
            lbd=lbd, volvol_2=eta_2, k=ks, T=T, order=0
        )
    )
    for month, T in mats.items()
}
# Out:
# m1_v: 0.23377006546917872, m1_y: 0.23377006546917872
# m2_v: 0.05516055069144629, m2_y: 0.05516055069144629
# m3_v: 0.01314045911904529, m3_y: 0.01314045911904529
# m1_v: 0.23284276922911862, m1_y: 0.23284276922911862
# m2_v: 0.055156965845922216, m2_y: 0.055156965845922216
# m3_v: 0.013302378821775724, m3_y: 0.013302378821775724
# m1_v: 0.2320781467230539, m1_y: 0.2320781467230539
# m2_v: 0.05515632443199488, m2_y: 0.05515632443199488
# m3_v: 0.013442976009387196, m3_y: 0.013442976009387196

# %%
fig, ax = plt.subplots(figsize=(8, 6))
for i, month in enumerate(mats.keys()):
    ax.plot(ks, 100 * impvol_vix_mixed[month], ".", color=COLORS[i], label=f"{month}")
    ax.plot(ks, 100 * impvol_vix_mixed_approx[month], "x", color=COLORS[i])
    # ax.plot(
    #     ks,
    #     100 * impvol_vix_mixed_approx_scipy[month],
    #     "+",
    #     color=COLORS[i],
    #     label=f"approx ({month}) scipy",
    # )
    # ax.plot(
    #     ks,
    #     100 * impvol_vix_mixed_approx_lognorm[month],
    #     "v",
    #     color=COLORS[i],
    #     label=f"approx ({month}) lognorm",
    # )
    # ax.plot(
    #     ks,
    #     100 * impvol_vix_mixed_approx_slognorm[month],
    #     "*",
    #     color=COLORS[i],
    #     label=f"approx ({month}) shifted lognorm",
    # )
    # ax.plot(
    #     ks,
    #     100 * impvol_vix_mixed_approx_series[month],
    #     "*",
    #     color=COLORS[i],
    #     label=f"approx ({month}) series",
    # )
ax.plot([], [], "kx", label="Approx")
ax.plot([], [], "k+", label="Expansion")
ax.set_xlabel(r"$k=\log(K/F)$")
ax.set_ylabel("VIX implied volatility in %")
ax.legend(ncol=3)
ax.set_ylim(10, 60)
plt.show()

# %% [markdown]
# ## VIX futures prices as a function of $T$

# %%
tab_t = np.linspace(1.0 / 365.0, 1.0, 10)

vix_fut_t = np.array(
    [
        rbergomi.price_vix_fut(
            T=T, n_mc=n_mc, n_disc=n_disc, rule="trap", lbd=lbd, eta_2=eta_2
        )
        for T in tab_t
    ]
)

# %%
vix_fut_t_approx = np.array(
    [
        rbergomi.price_vix_approx_mixed(
            T=T, lbd=lbd, eta_2=eta_2, order=3, opt_payoff="fut", K=0.0, n_quad=40
        )
        for T in tab_t
    ]
)

# %%
fig, ax = plt.subplots()
ax.plot(tab_t, 100.0 * vix_fut_t, ".r", label="MC")
ax.plot(tab_t, 100.0 * vix_fut_t_approx, "xr", label="approx")
ax.set_xlabel("$T$")
ax.set_ylabel("VIX futures price in %")
ax.legend()
plt.show()

# %% [markdown]
# # Misc

# %% [markdown]
# Try to approximate the integral
#
# $$
#     \int_{-\infty}^{B} (1 + b e ^{c y})^{1/2} \, \phi(y) \, dy
# $$

# %%
def integral(b, c, B):
    return integrate.quad(
        lambda y: np.sqrt(1 + b * np.exp(c * y)) * stats.norm.pdf(y), -np.inf, B
    )[0]


def integral_approx_small(b, c, B, order=3):
    # small expansion: |b * np.exp(c * B)| << 1
    term0 = stats.norm.cdf(B)
    if order == 0:
        return term0
    term1 = (b / 2.0) * np.exp(c**2 / 2.0) * stats.norm.cdf(B - c)
    if order == 1:
        return term0 + term1
    term2 = (-(b**2) / 8.0) * np.exp(2 * c**2) * stats.norm.cdf(B - 2 * c)
    if order == 2:
        return term0 + term1 + term2
    term3 = (b**3 / 16.0) * np.exp(9 * c**2 / 2.0) * stats.norm.cdf(B - 3 * c)
    if order == 3:
        return term0 + term1 + term2 + term3

    raise ValueError("order must be in {0,1,2,3}")


def integral_approx_large(b, c, B, order=3):
    # large expansion: |b * np.exp(c * B)| >> 1
    term0 = np.sqrt(b) * np.exp(c**2 / 8.0) * stats.norm.cdf(B - c / 2)
    if order == 0:
        return term0
    term1 = (1.0 / (2.0 * np.sqrt(b))) * np.exp(c**2 / 8.0) * stats.norm.cdf(B + c / 2)
    if order == 1:
        return term0 + term1

# %%
print("Numerical vs Approx integral")
b = 0.2
c = 1.0
B = 10
print("b =", b, "c =", c, "B =", B)
print(f"b * exp(c * B) = {b * np.exp(c * B)}")
print(f"Numerical: {integral(b, c, B)}")
print(f"Approx large b exp(c B): {integral_approx_large(b, c, B, order=1)}")
print(f"Approx small b exp(c B): {integral_approx_small(b, c, B, order=0)}")
